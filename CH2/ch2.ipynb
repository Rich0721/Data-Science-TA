# %% [markdown]
#  測試Selenium

# %%
from selenium import webdriver
imdb_home = "http://www.google.com"
driver = webdriver.Firefox(executable_path="./geckodriver.exe") # Use Firefox
driver.get(imdb_home)

# %% [markdown]
#  Selenium 實作開始

# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
# available since 2.4.0
from selenium.webdriver.support.ui import WebDriverWait
# available since 2.26.0
from selenium.webdriver.support import expected_conditions as EC
from time import sleep
driver = webdriver.Firefox(executable_path="./geckodriver.exe")
 
# 去 google
driver.get("http://www.google.com")
WebDriverWait(driver, 20)
# 找到搜尋框
inputElement = driver.find_element_by_name("q")
 
# 搜尋框輸入字
inputElement.send_keys("逢甲大學")
 
# 提交
inputElement.submit()
 
try:
    # 直到標題有逢甲大學
    WebDriverWait(driver, 20).until(EC.title_contains("逢甲大學"))
    sleep(1)
    first_result_elem = driver.find_element_by_xpath("/html/body/div[7]/div[2]/div[10]/div[1]/div[2]/div/div[2]/div[2]/div/div/div[1]/div/div/div/div[1]/a/h3/span")
    # 按下搜尋結果連結
    first_result_elem.click()
    
except TimeoutException:
    print('time out')

driver.close()

# %% [markdown]
# 動態網頁案例1實作開始

# %%
##设置一定的点击次数
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import re

browser = webdriver.Firefox(executable_path="./geckodriver.exe")

# 去豆瓣
browser.get('https://movie.douban.com/tag/#/?sort=T&range=0,10&tags=')

#瀏覽器解釋JS腳本是需要時間的，但實際上這個時間並不好確定，如果我們手動設定時間間隔的話，設置多了浪費時間，設置少了又會丟失數據
#implictly_wait函數則完美解決了這個問題，給他一個時間參數，它會只能等待，當js完全解釋完畢就會自動執行下一步。
browser.implicitly_wait(3)

#讓程式休息3毫秒
time.sleep(3)

#選擇勵志電影類型
browser.find_element_by_xpath('//*[@id="app"]/div/div[1]/div[1]/ul[4]/li[6]/span').click()


for i in range(5):
    #找到加载更多這個按鈕並按下去
    browser.find_element_by_link_text("加载更多").click()
    
    ###如果網頁沒有完全加載，會出現點擊錯誤，會點擊到某個電影頁面，所以加了一個睡眠時間。
    time.sleep(5)
    
    ##browswe.page_source是點擊5次後的源碼，用Beautiful Soup解析源碼
    soup = BeautifulSoup(browser.page_source, 'html.parser')

items = soup.find('div', class_=re.compile('list-wp'))
for item in items.find_all('a'):
    
    #將標題抓下來
    Title = item.find('span', class_='title').text
    
    #將評分抓下來
    Rate = item.find('span', class_='rate').text
    print(Title,Rate)

#關閉瀏覽器
browser.close()
# Out:
# 肖申克的救赎 9.7
# 这个杀手不太冷 9.4
# 阿甘正传 9.5
# 泰坦尼克号 9.4
# 霸王别姬 9.6
# 海上钢琴师 9.3
# 大话西游之大圣娶亲 9.2
# 楚门的世界 9.3
# 大话西游之月光宝盒 9.0
# 美丽人生 9.5
# 唐伯虎点秋香 8.6
# 剪刀手爱德华 8.7
# 辛德勒的名单 9.5
# 喜剧之王 8.8
# 七宗罪 8.8
# 狮子王 9.0
# 情书 8.9
# 闻香识女人 9.1
# 黑客帝国 9.0
# 沉默的羔羊 8.8
# 搏击俱乐部 9.0
# 活着 9.3
# 低俗小说 8.9
# 重庆森林 8.7
# 东邪西毒 8.6
# 心灵捕手 8.9
# 射雕英雄传之东成西就 8.7
# 拯救大兵瑞恩 9.0
# 勇敢的心 8.9
# 幽灵公主 8.9
# 阳光灿烂的日子 8.8
# 九品芝麻官 8.5
# 春光乍泄 8.9
# 两杆大烟枪 9.1
# 菊次郎的夏天 8.8
# 爱在黎明破晓前 8.8
# 青蛇 8.6
# 饮食男女 9.1
# 阿飞正传 8.5
# 小鬼当家 8.3
# 甜蜜蜜 8.8
# 第六感 8.9
# 新龙门客栈 8.6
# 玩具总动员 8.5
# 食神 8.0
# 变脸 8.5
# 纵横四海 8.8
# 侧耳倾听 8.9
# 大内密探零零发 7.9
# 猜火车 8.5
# 国产凌凌漆 8.3
# 武状元苏乞儿 7.9
# 侏罗纪公园 8.2
# 教父3 8.9
# 黑衣人 8.2
# 终结者2：审判日 8.7
# 小鞋子 9.2
# 逃学威龙 7.9
# 诺丁山 8.0
# 鹿鼎记 8.1
# 美国丽人 8.5
# 碟中谍 8.2
# 变相怪杰 7.9
# 百变星君 7.7
# 花木兰 7.9
# 甲方乙方 8.3
# 独立日 8.1
# 夜访吸血鬼 8.3
# 英国病人 8.5
# 喜宴 8.9
# 玩具总动员2 8.3
# 整蛊专家 7.7
# 燃情岁月 8.8
# 勇闯夺命岛 8.6
# 家有喜事 8.4
# 西雅图未眠夜 7.9
# 绿里奇迹 8.8
# 人鬼情未了 8.2
# 宝莲灯 8.2
# 罗拉快跑 8.1
# 赌圣 7.8
# 审死官 7.8
# 赌侠 7.7
# 牯岭街少年杀人事件 8.8
# 红猪 8.5
# 逃学威龙2 7.7
# 木乃伊 7.8
# 大红灯笼高高挂 8.6
# 美女与野兽 8.5
# 非常嫌疑犯 8.6
# 完美的世界 9.1
# 未麻的部屋 9.0
# 还珠格格 8.4
# 暗战 8.5
# 情人 8.2
# 小鬼当家2 8.0
# 精灵鼠小弟 7.7
# 十二猴子 8.2
# 老友记 第一季 9.7
# 笑傲江湖2：东方不败 8.4
# 鹿鼎记2：神龙教 8.0
# 廊桥遗梦 8.7
# 千钧一发 8.8
# 侏罗纪公园2：失落的世界 7.6
# 心慌方 7.9
# 末路狂花 8.8
# 空中监狱 8.2
# 第五元素 8.0
# 黄飞鸿 8.2
# 方世玉 7.9
# 枪火 8.7
# 倩女幽魂2：人间道 8.0
# 回魂夜 8.0
# 有话好好说 8.3
# 破坏之王 7.7
# 一树梨花压海棠 8.2
# 我是谁 7.6
# 笑林小子 7.9
# 倚天屠龙记之魔教教主 7.7
# 落水狗 8.4

# %% [markdown]
# 動態網頁案例2實作開始

# %%
import requests
headers = {'cookie':'uuid_tt_dd=3844871280714138949_20171108; kd_user_id=e61e2f88-9c4f-4cf7-88c7-68213cac17f7; UN=qq_40963426; BT=1521452212412; Hm_ct_6bcd52f51e9b3dce32bec4a3997715ac=1788*1*PC_VC; smidV2=20180626144357b069d2909d23ff73c3bc90ce183c8c57003acfcec7f57dd70; __utma=17226283.14643699.1533350144.1533350144.1534431588.2; __utmz=17226283.1533350144.1.1.utmcsr=zhuanlan.zhihu.com|utmccn=(referral)|utmcmd=referral|utmcct=/p/39165199/edit; TY_SESSION_ID=f49bdedd-c1d4-4f86-b254-22ab2e8f02f6; ViewMode=contents; UM_distinctid=165471259cb3e-02c5602643907b-5d4e211f-100200-165471259cc86; dc_session_id=10_1534471423488.794042; dc_tos=pdlzzq; Hm_lvt_6bcd52f51e9b3dce32bec4a3997715ac=1534515139,1534515661,1534515778,1534515830; Hm_lpvt_6bcd52f51e9b3dce32bec4a3997715ac=1534515830; ADHOC_MEMBERSHIP_CLIENT_ID1.0=d480c872-d4e9-33d9-d0e5-f076fc76aa83',
           'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'}
def get_page():
    r =requests.get('https://www.csdn.net/api/articles?type=more&category=home&shown_offset=1534516237069160',headers=headers)
    d=r.json()#一般ajax返回的都是json格式数据，将返回的数据json格式化，.json()是requests库自带函数
    articles = d['articles']#字典形式
    for article in articles:
        yield {
            'article':article['title'],
            'Link':article['user_url'],
            'View':article['views']
               }
for i in get_page():
    print(i)
# Out:
# {'article': '组建新基建时代「开发者湘军」！', 'Link': 'https://blog.csdn.net/zxff716', 'View': 0}
# {'article': 'dubbo学习之本地存根实践', 'Link': 'https://blog.csdn.net/xuan_lu', 'View': '2819'}
# {'article': 'python爬取酷我音乐(收费也可)', 'Link': 'https://blog.csdn.net/qq_45931878', 'View': '8490'}
# {'article': '这些前端框架，让你的开发更高效率，高质量，你用过吗？', 'Link': 'https://blog.csdn.net/gitchatxiaomi', 'View': '10860'}
# {'article': '使用这些不太常用的 CSS 属性，让我在前端布局效率上，又提高了一个层次！', 'Link': 'https://blog.csdn.net/qq449245884', 'View': '471'}
# {'article': '【STM32】串口通信---用代码与芯片对话', 'Link': 'https://blog.csdn.net/qq_43328313', 'View': '1608'}
# {'article': '【答学员问】你们从培训机构毕业后都找到什么工作？', 'Link': 'https://blog.csdn.net/xinshuzhan', 'View': '11816'}
# {'article': '42图揭秘，「后端技术学些啥」', 'Link': 'https://blog.csdn.net/L15519543837', 'View': '2454'}
# {'article': '人生，有时候需要一些摸鱼的快乐时光', 'Link': 'https://blog.csdn.net/qq_43762191', 'View': '4129'}
# {'article': '力扣(LeetCode)刷题，简单题(第23期)', 'Link': 'https://blog.csdn.net/m0_38106923', 'View': '1455'}

# %% [markdown]
# 遠端伺服器爬蟲

# %% [markdown]
# 作業1(方法1)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
imdb_home = "https://www.ptt.cc/bbs/NBA/search?q=%E6%B9%96%E4%BA%BA"
driver = webdriver.Firefox(executable_path="C:\geckodriver.exe") # Use Firefox
driver.get(imdb_home)

soup = BeautifulSoup(driver.page_source, 'html.parser')
results = soup.select("div.title")
for item in results:
    a_item = item.select_one("a")
    title = item.text
    if a_item:
        print(title)    
driver.close()
# Out:
# [討論] 火箭的出手及湖人的防守策略
#
#
# [討論] 公鹿/湖人幾個球員表現
#
#
# [情報] 當G2G3 Rondo在場上 湖人比火箭多得35分
#
#
# [Live] 湖人 @ 火箭
#
#
# [專欄]朗多成關鍵因子詹皇壓箱寶未出湖人底蘊猶厚
#
#
# [花邊] Westbrook 2010年推特被挖：湖人還是火箭
#
#
# [花邊] 湖人5小在場上的正負值為+21
#
#
# [情報] Gordon：湖人今日使用3-2區域聯防，我們
#
#
# [Live] 火箭 @ 湖人
#
#
# Re: [討論] 為什麼湖人籃板搶不贏火箭？
#
#
# [專欄] 火箭以小搏大強勢錯位與卡位 湖人尋覓破解
#
#
# Re: [討論] 為什麼湖人籃板搶不贏火箭？
#
#
# [情報] 湖人第二戰將穿黑曼巴球衣
#
#
# Re: [討論] 為什麼湖人籃板搶不贏火箭？
#
#
# [新聞] 格林講評再語出驚人 長人都該祈禱湖人打
#
#
# Re: [討論] 為什麼湖人籃板搶不贏火箭？
#
#
# Re: [討論] 為什麼湖人籃板搶不贏火箭？
#
#
# [討論] 為什麼湖人籃板搶不贏火箭？
#
#
# [情報] 湖人本季季後賽團隊三分低於30%時皆輸球
#
#
# [情報] 湖人G1第四節初段的陣容是本賽季第一次出

# %% [markdown]
# 作業(方法2)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
from selenium.webdriver.common.keys import Keys

imdb_home = "https://www.ptt.cc/bbs/NBA/index.html"
driver = webdriver.Firefox(executable_path="C:\geckodriver.exe") # Use Firefox
driver.get(imdb_home)


driver.find_element_by_name("q").send_keys("湖人")
driver.find_element_by_name("q").send_keys(Keys.ENTER) 

soup = BeautifulSoup(driver.page_source, 'html.parser')
results = soup.select("div.title")
for item in results:
    a_item = item.select_one("a")
    title = item.text
    if a_item:
        print(title)
# Out:
# [情報] 76人管理層已經認真討論過交易得到保羅的
#
#
# Re: [討論] 可愛這個人
#
#
# [公告] 板規v6.8
#
#
# [公告] 第一次被退文，可在三天後刪除退文
#
#
# [公告] 8/15實施季後賽條款 以及提醒事項(發P)
#
#
# [情報] Playoffs Schedule 19–20
